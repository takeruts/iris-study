# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import pylab
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
debug = False

# %%
iris = datasets.load_iris()
x_vals = np.array([x[0:4] for x in iris.data])
y_vals = np.array([y for y in iris.target])

# Transform to Onehot
y_vals = np.array(y_vals).reshape(1, -1).transpose()
encoder = OneHotEncoder(n_values=max(y_vals)+1)
y_vals = encoder.fit_transform(y_vals).toarray()

# %%
# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 4
#中間層サイズ
hidden_layer1_size = 64
hidden_layer2_size = 128
hidden_layer3_size = 128

num_hidden_layers = 3
#出力層サイズ
output_layer_size = 3
# 訓練データ、テストデータの抽出繰り返し数
tests_num = 10
# バッチ処理繰り返し数
iters_num = 1000
# ミニバッチサイズ
batch_size = 40
# 学習率
learning_rate=0.001
# 描写頻度
plot_interval= 50

# Adam parameters
beta1 = 0.9
beta2 = 0.999

# 正則化強度設定 ======================================
weight_decay_lambda = 0.01
# =================================================

# ドリップアウト
dropout_ratio = 0.4

# %%
# ReLU関数
def relu(x):
    return np.maximum(0, x)
# 出力層の活性化関数
# ソフトマックス関数
def softmax(x):
    if x.ndim == 2:
        x = x.T
        x = x - np.max(x, axis=0)
        y = np.exp(x) / np.sum(np.exp(x), axis=0)
        return y.T

    x = x - np.max(x) # オーバーフロー対策
    return np.exp(x) / np.sum(np.exp(x))

# ReLU関数の導関数
def d_relu(x):
    return np.where( x > 0, 1, 0)
# ソフトマックスとクロスエントロピーの複合導関数
def d_softmax_with_loss(d, y):
    batch_size = d.shape[0]
    if d.size == y.size: # 教師データがone-hot-vectorの場合
        dx = (y - d) / batch_size
    else:
        dx = y.copy()
        dx[np.arange(batch_size), d] -= 1
        dx = dx / batch_size
    return dx

def cross_entropy_error(d, y):
    y_max = np.argmax(y, axis=1)
    d_max = np.argmax(d, axis=1)

    batch_size = y_max.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), d_max] + 1e-7)) / batch_size

def accuracy(d, y):
    y_max = np.argmax(y, axis=1)
    d_max = np.argmax(d, axis=1)
    
    batch_size = float(y_max.shape[0])
    return np.sum(y_max == d_max) / batch_size

# %%
# 初期設定
def init_network():
    network = {} 
    # Heの初期値    
    network['W1'] = np.random.randn(input_layer_size, hidden_layer1_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    network['W2'] = np.random.randn(hidden_layer1_size, hidden_layer2_size) / np.sqrt(hidden_layer1_size) * np.sqrt(2)
    network['W3'] = np.random.randn(hidden_layer2_size, hidden_layer3_size) / np.sqrt(hidden_layer2_size) * np.sqrt(2)
    network['W4'] = np.random.randn(hidden_layer3_size, output_layer_size) / np.sqrt(hidden_layer3_size) * np.sqrt(2)

    network['b1'] = np.zeros(hidden_layer1_size)
    network['b2'] = np.zeros(hidden_layer2_size)
    network['b3'] = np.zeros(hidden_layer3_size)
    network['b4'] = np.zeros(output_layer_size)

    return network

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask

# %%
# 順伝播
def forward(network, x, train_flg):
    W = {}
    dropout = {}
    W1, W2, W3, W4 = network['W1'], network['W2'], network['W3'], network['W4']
    b1, b2, b3, b4  = network['b1'], network['b2'], network['b3'], network['b4']

    for idx in range(num_hidden_layers):
        dropout['u' + str(idx+1)] = Dropout(dropout_ratio)
        
    # 1st Layer
    u1 = np.dot(x, W1) + b1
    u1 = dropout['u1'].forward(u1, train_flg=train_flg)
    z1 = relu(u1)
    # 2nd Layer
    u2 = np.dot(z1, W2) + b2
    u2 = dropout['u2'].forward(u2, train_flg=train_flg)
    z2 = relu(u2)
    #3rd Layer
    u3 = np.dot(z2, W3) + b3
    u3 = dropout['u3'].forward(u3, train_flg=train_flg)
    z3 = relu(u3)
    #4th Layer
    u4 = np.dot(z3, W4) + b4
    y  = softmax(u4)

    return z1, z2, z3, y, dropout

# %%
# 誤差逆伝播
def backward(x, d, z1, z2, z3, y, dropout):
    grad = {}
    
    W1, W2, W3, W4 = network['W1'], network['W2'], network['W3'], network['W4']
    b1, b2, b3, b4 = network['b1'], network['b2'], network['b3'], network['b4']
    # 出力層でのデルタ
    delta4 = d_softmax_with_loss(d, y)
    grad['b4'] = np.sum(delta4, axis=0)
    grad['W4'] = np.dot(z3.T, delta4) + weight_decay_lambda * W4

    delta3 = np.dot(delta4, W4.T) * d_relu(z3)
    delta3 = dropout['u3'].backward(delta3)
    grad['b3'] = np.sum(delta3, axis=0)
    grad['W3'] = np.dot(z2.T, delta3) + weight_decay_lambda * W3
    # 2層でのデルタ       
    delta2 = np.dot(delta3, W3.T) * d_relu(z2)
    delta2 = dropout['u2'].backward(delta2)
    grad['b2'] = np.sum(delta2, axis=0)
    grad['W2'] = np.dot(z1.T, delta2) + weight_decay_lambda * W2
    # 1層でのデルタ       
    delta1 = np.dot(delta2, W2.T) * d_relu(z1)
    delta1 = dropout['u1'].backward(delta1)
    grad['b1'] = np.sum(delta1, axis=0)
    grad['W1'] = np.dot(x.T, delta1) + weight_decay_lambda * W1

    return grad

# %%
# パラメータの初期化
network = init_network()

losses = []
losses_test = []
accuracies = []
accuracies_test = []

for loop in range(tests_num):
    x_train, x_test, d_train, d_test = train_test_split(x_vals, y_vals, test_size=0.2, random_state=None,)
    train_size = len(x_train)

    print("Loop" + str(loop) + " データ読み込み完了")
    if debug:
        print("x_train", x_train.shape)
        print("x_test", x_test.shape)
        print("d_train", d_train.shape)
        print("d_test", d_test.shape)

    for i in range(iters_num):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        d_batch = d_train[batch_mask]
        #d_batch = d_batch[:, np.newaxis]

        z1, z2, z3, y, dropout = forward(network, x_batch, train_flg=True)
        grad = backward(x_batch, d_batch, z1, z2, z3, y, dropout)

        #for Test
        z1_test, z2_test, z3_test, y_test, dropout = forward(network, x_test, train_flg=False)

        # Adam ====================================================
        if i == 0:
            m = {}
            v = {}

        learning_rate_t  = learning_rate * np.sqrt(1.0 - beta2 ** (i + 1)) / (1.0 - beta1 ** (i + 1))

        for key in ('W1', 'W2', 'W3','W4', 'b1', 'b2', 'b3', 'b4'):

            if i == 0:
                m[key] = np.zeros_like(network[key])
                v[key] = np.zeros_like(network[key])

            m[key] += (1 - beta1) * (grad[key] - m[key])
            v[key] += (1 - beta2) * (grad[key] ** 2 - v[key])            

            network[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)


        # =========================================================

        #     print('loss',functions.least_square(d_batch, y))
        if (i + 1) % plot_interval == 0:
            loss = cross_entropy_error(d_batch, y)
            losses.append(loss)
            acc = accuracy(d_batch, y)
            accuracies.append(acc)

            loss_test = cross_entropy_error(d_test, y_test)
            losses_test.append(loss_test)
            acc_test = accuracy(d_test, y_test)
            accuracies_test.append(acc_test)

            print('                : ' + str(i+1) + '. 誤差(テスト) = ' + str(loss_test))
            print('                : ' + str(i+1) + '. 精度(テスト) = ' + str(acc_test))
# Out:
# Loop0 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.8368829261841596
#                 : 20. 精度(テスト) = 0.7
#                 : 40. 誤差(テスト) = 0.745410752667194
#                 : 40. 精度(テスト) = 0.7
#                 : 60. 誤差(テスト) = 0.7481048313446089
#                 : 60. 精度(テスト) = 0.6
#                 : 80. 誤差(テスト) = 0.6592394012805645
#                 : 80. 精度(テスト) = 0.7
#                 : 100. 誤差(テスト) = 0.6380024541234705
#                 : 100. 精度(テスト) = 0.7
#                 : 120. 誤差(テスト) = 0.6011663539331964
#                 : 120. 精度(テスト) = 0.7
#                 : 140. 誤差(テスト) = 0.5581928069460831
#                 : 140. 精度(テスト) = 0.7
#                 : 160. 誤差(テスト) = 0.5062024202924326
#                 : 160. 精度(テスト) = 0.7
#                 : 180. 誤差(テスト) = 0.4701400044934679
#                 : 180. 精度(テスト) = 0.7
#                 : 200. 誤差(テスト) = 0.44893520525173986
#                 : 200. 精度(テスト) = 0.7333333333333333
#                 : 220. 誤差(テスト) = 0.4448721778507033
#                 : 220. 精度(テスト) = 0.8
#                 : 240. 誤差(テスト) = 0.4382422252302616
#                 : 240. 精度(テスト) = 0.7
#                 : 260. 誤差(テスト) = 0.42724304884090536
#                 : 260. 精度(テスト) = 0.7
#                 : 280. 誤差(テスト) = 0.4142099514936082
#                 : 280. 精度(テスト) = 0.7333333333333333
#                 : 300. 誤差(テスト) = 0.4071220270663767
#                 : 300. 精度(テスト) = 0.7
#                 : 320. 誤差(テスト) = 0.39620168193764094
#                 : 320. 精度(テスト) = 0.8
#                 : 340. 誤差(テスト) = 0.3915424709466045
#                 : 340. 精度(テスト) = 0.7333333333333333
#                 : 360. 誤差(テスト) = 0.3718582418376621
#                 : 360. 精度(テスト) = 0.7333333333333333
#                 : 380. 誤差(テスト) = 0.3710604473974511
#                 : 380. 精度(テスト) = 0.8
#                 : 400. 誤差(テスト) = 0.3583436530344202
#                 : 400. 精度(テスト) = 0.8
#                 : 420. 誤差(テスト) = 0.3592447069269638
#                 : 420. 精度(テスト) = 0.8
#                 : 440. 誤差(テスト) = 0.3598182269576859
#                 : 440. 精度(テスト) = 0.8
#                 : 460. 誤差(テスト) = 0.33789407579587044
#                 : 460. 精度(テスト) = 0.8333333333333334
#                 : 480. 誤差(テスト) = 0.3541243208498291
#                 : 480. 精度(テスト) = 0.8
#                 : 500. 誤差(テスト) = 0.3535821071683436
#                 : 500. 精度(テスト) = 0.8
#                 : 520. 誤差(テスト) = 0.3227119547550116
#                 : 520. 精度(テスト) = 0.8333333333333334
#                 : 540. 誤差(テスト) = 0.3020730842619758
#                 : 540. 精度(テスト) = 0.9333333333333333
#                 : 560. 誤差(テスト) = 0.31910575127383983
#                 : 560. 精度(テスト) = 0.8333333333333334
#                 : 580. 誤差(テスト) = 0.2877861044764015
#                 : 580. 精度(テスト) = 0.9333333333333333
#                 : 600. 誤差(テスト) = 0.2659469982976818
#                 : 600. 精度(テスト) = 0.9333333333333333
#                 : 620. 誤差(テスト) = 0.2685061040370964
#                 : 620. 精度(テスト) = 0.9333333333333333
#                 : 640. 誤差(テスト) = 0.24175637329435148
#                 : 640. 精度(テスト) = 0.9333333333333333
#                 : 660. 誤差(テスト) = 0.2157643522267959
#                 : 660. 精度(テスト) = 0.9333333333333333
#                 : 680. 誤差(テスト) = 0.23159308018950434
#                 : 680. 精度(テスト) = 0.9333333333333333
#                 : 700. 誤差(テスト) = 0.2257715894857135
#                 : 700. 精度(テスト) = 0.9333333333333333
#                 : 720. 誤差(テスト) = 0.2253117187231894
#                 : 720. 精度(テスト) = 0.9333333333333333
#                 : 740. 誤差(テスト) = 0.18955545651931052
#                 : 740. 精度(テスト) = 0.9333333333333333
#                 : 760. 誤差(テスト) = 0.19716204182880573
#                 : 760. 精度(テスト) = 0.9333333333333333
#                 : 780. 誤差(テスト) = 0.17233448905771043
#                 : 780. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.17181404524000088
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.15402145331319486
#                 : 820. 精度(テスト) = 0.9666666666666667
#                 : 840. 誤差(テスト) = 0.152374712047569
#                 : 840. 精度(テスト) = 0.9333333333333333
#                 : 860. 誤差(テスト) = 0.13596604163517798
#                 : 860. 精度(テスト) = 0.9666666666666667
#                 : 880. 誤差(テスト) = 0.13400920860385243
#                 : 880. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.1292849676769185
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 920. 誤差(テスト) = 0.13792661578461562
#                 : 920. 精度(テスト) = 0.9333333333333333
#                 : 940. 誤差(テスト) = 0.11244269076721505
#                 : 940. 精度(テスト) = 0.9666666666666667
#                 : 960. 誤差(テスト) = 0.15064666550786784
#                 : 960. 精度(テスト) = 0.9333333333333333
#                 : 980. 誤差(テスト) = 0.11913483315505217
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.11571305071721065
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop1 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.14317014726954333
#                 : 20. 精度(テスト) = 0.9666666666666667
#                 : 40. 誤差(テスト) = 0.19167343808803491
#                 : 40. 精度(テスト) = 0.9333333333333333
#                 : 60. 誤差(テスト) = 0.12022347261173769
#                 : 60. 精度(テスト) = 0.9666666666666667
#                 : 80. 誤差(テスト) = 0.13423307385020689
#                 : 80. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.13006935774804199
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 120. 誤差(テスト) = 0.14418752713419894
#                 : 120. 精度(テスト) = 0.9666666666666667
#                 : 140. 誤差(テスト) = 0.1341630011893045
#                 : 140. 精度(テスト) = 0.9666666666666667
#                 : 160. 誤差(テスト) = 0.11961610560750231
#                 : 160. 精度(テスト) = 0.9666666666666667
#                 : 180. 誤差(テスト) = 0.13777767131415145
#                 : 180. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.14251793293895282
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 220. 誤差(テスト) = 0.1494482899793996
#                 : 220. 精度(テスト) = 0.9666666666666667
#                 : 240. 誤差(テスト) = 0.10842022988077818
#                 : 240. 精度(テスト) = 0.9666666666666667
#                 : 260. 誤差(テスト) = 0.10871386666440411
#                 : 260. 精度(テスト) = 0.9666666666666667
#                 : 280. 誤差(テスト) = 0.11792653916778702
#                 : 280. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.11648293232739305
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 320. 誤差(テスト) = 0.11830175349468414
#                 : 320. 精度(テスト) = 0.9666666666666667
#                 : 340. 誤差(テスト) = 0.1344259339076367
#                 : 340. 精度(テスト) = 0.9666666666666667
#                 : 360. 誤差(テスト) = 0.1507701904066505
#                 : 360. 精度(テスト) = 0.9666666666666667
#                 : 380. 誤差(テスト) = 0.13000702225504276
#                 : 380. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.10196529483069236
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 420. 誤差(テスト) = 0.10352374926882683
#                 : 420. 精度(テスト) = 0.9666666666666667
#                 : 440. 誤差(テスト) = 0.10266879672574274
#                 : 440. 精度(テスト) = 0.9666666666666667
#                 : 460. 誤差(テスト) = 0.11293100479272623
#                 : 460. 精度(テスト) = 0.9666666666666667
#                 : 480. 誤差(テスト) = 0.1204183829781022
#                 : 480. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.13357316942493486
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 520. 誤差(テスト) = 0.11673150366424144
#                 : 520. 精度(テスト) = 0.9666666666666667
#                 : 540. 誤差(テスト) = 0.1323861320319256
#                 : 540. 精度(テスト) = 0.9666666666666667
#                 : 560. 誤差(テスト) = 0.09517836845560468
#                 : 560. 精度(テスト) = 0.9666666666666667
#                 : 580. 誤差(テスト) = 0.10563659267773194
#                 : 580. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.10666213211272252
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 620. 誤差(テスト) = 0.11541509844339205
#                 : 620. 精度(テスト) = 0.9666666666666667
#                 : 640. 誤差(テスト) = 0.09720438209245495
#                 : 640. 精度(テスト) = 0.9666666666666667
#                 : 660. 誤差(テスト) = 0.12401940506632633
#                 : 660. 精度(テスト) = 0.9666666666666667
#                 : 680. 誤差(テスト) = 0.13423817634165
#                 : 680. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.09390008417735586
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 720. 誤差(テスト) = 0.09398155856925929
#                 : 720. 精度(テスト) = 0.9666666666666667
#                 : 740. 誤差(テスト) = 0.12655385684491308
#                 : 740. 精度(テスト) = 0.9666666666666667
#                 : 760. 誤差(テスト) = 0.10735419283791402
#                 : 760. 精度(テスト) = 0.9666666666666667
#                 : 780. 誤差(テスト) = 0.10664520264136411
#                 : 780. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.10264913328062004
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.09106069318205098
#                 : 820. 精度(テスト) = 0.9666666666666667
#                 : 840. 誤差(テスト) = 0.09044413491616292
#                 : 840. 精度(テスト) = 0.9666666666666667
#                 : 860. 誤差(テスト) = 0.11541666323135504
#                 : 860. 精度(テスト) = 0.9666666666666667
#                 : 880. 誤差(テスト) = 0.11144462937343644
#                 : 880. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.1251946802219449
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 920. 誤差(テスト) = 0.12648893179211354
#                 : 920. 精度(テスト) = 0.9666666666666667
#                 : 940. 誤差(テスト) = 0.120235462608946
#                 : 940. 精度(テスト) = 0.9666666666666667
#                 : 960. 誤差(テスト) = 0.12990919869041212
#                 : 960. 精度(テスト) = 0.9666666666666667
#                 : 980. 誤差(テスト) = 0.0969473366794488
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.09592499801273575
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop2 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.04414639481226774
#                 : 20. 精度(テスト) = 1.0
#                 : 40. 誤差(テスト) = 0.04445575286169024
#                 : 40. 精度(テスト) = 1.0
#                 : 60. 誤差(テスト) = 0.07061422258873001
#                 : 60. 精度(テスト) = 0.9666666666666667
#                 : 80. 誤差(テスト) = 0.04207859322733564
#                 : 80. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.043052802202162226
#                 : 100. 精度(テスト) = 1.0
#                 : 120. 誤差(テスト) = 0.032191787503065165
#                 : 120. 精度(テスト) = 1.0
#                 : 140. 誤差(テスト) = 0.03392503612879103
#                 : 140. 精度(テスト) = 1.0
#                 : 160. 誤差(テスト) = 0.043407057254790556
#                 : 160. 精度(テスト) = 1.0
#                 : 180. 誤差(テスト) = 0.04355406080833842
#                 : 180. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.08453241593484824
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 220. 誤差(テスト) = 0.04144839315582438
#                 : 220. 精度(テスト) = 1.0
#                 : 240. 誤差(テスト) = 0.05984065732336431
#                 : 240. 精度(テスト) = 0.9666666666666667
#                 : 260. 誤差(テスト) = 0.048315766971611815
#                 : 260. 精度(テスト) = 0.9666666666666667
#                 : 280. 誤差(テスト) = 0.039487257426985146
#                 : 280. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.044405066160702805
#                 : 300. 精度(テスト) = 1.0
#                 : 320. 誤差(テスト) = 0.04340484469522156
#                 : 320. 精度(テスト) = 1.0
#                 : 340. 誤差(テスト) = 0.034612965044896776
#                 : 340. 精度(テスト) = 1.0
#                 : 360. 誤差(テスト) = 0.034008855497556736
#                 : 360. 精度(テスト) = 1.0
#                 : 380. 誤差(テスト) = 0.04294637465193956
#                 : 380. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.054868832081243275
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 420. 誤差(テスト) = 0.059109308604052405
#                 : 420. 精度(テスト) = 0.9666666666666667
#                 : 440. 誤差(テスト) = 0.05036609796278348
#                 : 440. 精度(テスト) = 0.9666666666666667
#                 : 460. 誤差(テスト) = 0.048656101128036
#                 : 460. 精度(テスト) = 0.9666666666666667
#                 : 480. 誤差(テスト) = 0.061857463696452036
#                 : 480. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.057938110265208606
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 520. 誤差(テスト) = 0.037456855049551735
#                 : 520. 精度(テスト) = 1.0
#                 : 540. 誤差(テスト) = 0.04113410239254664
#                 : 540. 精度(テスト) = 1.0
#                 : 560. 誤差(テスト) = 0.06031997832713483
#                 : 560. 精度(テスト) = 0.9666666666666667
#                 : 580. 誤差(テスト) = 0.061810270844433
#                 : 580. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.05824571446057752
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 620. 誤差(テスト) = 0.056099485303997915
#                 : 620. 精度(テスト) = 0.9666666666666667
#                 : 640. 誤差(テスト) = 0.08313197725217052
#                 : 640. 精度(テスト) = 0.9666666666666667
#                 : 660. 誤差(テスト) = 0.06510044134691374
#                 : 660. 精度(テスト) = 0.9666666666666667
#                 : 680. 誤差(テスト) = 0.04899539643711036
#                 : 680. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.043531782584436934
#                 : 700. 精度(テスト) = 1.0
#                 : 720. 誤差(テスト) = 0.054522113590137145
#                 : 720. 精度(テスト) = 0.9666666666666667
#                 : 740. 誤差(テスト) = 0.057042504369227656
#                 : 740. 精度(テスト) = 0.9666666666666667
#                 : 760. 誤差(テスト) = 0.04292589196136063
#                 : 760. 精度(テスト) = 1.0
#                 : 780. 誤差(テスト) = 0.03858696130503667
#                 : 780. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.043461037346134185
#                 : 800. 精度(テスト) = 1.0
#                 : 820. 誤差(テスト) = 0.035948776276086655
#                 : 820. 精度(テスト) = 1.0
#                 : 840. 誤差(テスト) = 0.05262921534141555
#                 : 840. 精度(テスト) = 0.9666666666666667
#                 : 860. 誤差(テスト) = 0.04896867740203845
#                 : 860. 精度(テスト) = 0.9666666666666667
#                 : 880. 誤差(テスト) = 0.04232697517162736
#                 : 880. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.0324027039557784
#                 : 900. 精度(テスト) = 1.0
#                 : 920. 誤差(テスト) = 0.03121617140597129
#                 : 920. 精度(テスト) = 1.0
#                 : 940. 誤差(テスト) = 0.05032300249765565
#                 : 940. 精度(テスト) = 0.9666666666666667
#                 : 960. 誤差(テスト) = 0.056611724803556314
#                 : 960. 精度(テスト) = 0.9666666666666667
#                 : 980. 誤差(テスト) = 0.04686596194883607
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.05341824894663117
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop3 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.11115046611189673
#                 : 20. 精度(テスト) = 0.9666666666666667
#                 : 40. 誤差(テスト) = 0.10919577506028719
#                 : 40. 精度(テスト) = 0.9666666666666667
#                 : 60. 誤差(テスト) = 0.10621839240044209
#                 : 60. 精度(テスト) = 0.9666666666666667
#                 : 80. 誤差(テスト) = 0.11521675520753921
#                 : 80. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.11870011194114291
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 120. 誤差(テスト) = 0.10612074812533452
#                 : 120. 精度(テスト) = 0.9666666666666667
#                 : 140. 誤差(テスト) = 0.1058198956269438
#                 : 140. 精度(テスト) = 0.9666666666666667
#                 : 160. 誤差(テスト) = 0.11725482616967578
#                 : 160. 精度(テスト) = 0.9666666666666667
#                 : 180. 誤差(テスト) = 0.11576627252448787
#                 : 180. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.10528515200678387
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 220. 誤差(テスト) = 0.10888980183421659
#                 : 220. 精度(テスト) = 0.9666666666666667
#                 : 240. 誤差(テスト) = 0.13275203227027743
#                 : 240. 精度(テスト) = 0.9666666666666667
#                 : 260. 誤差(テスト) = 0.1126879504178246
#                 : 260. 精度(テスト) = 0.9666666666666667
#                 : 280. 誤差(テスト) = 0.11685537543132545
#                 : 280. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.11281622060490902
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 320. 誤差(テスト) = 0.11984949001927979
#                 : 320. 精度(テスト) = 0.9666666666666667
#                 : 340. 誤差(テスト) = 0.10732953032990197
#                 : 340. 精度(テスト) = 0.9666666666666667
#                 : 360. 誤差(テスト) = 0.11146239737774884
#                 : 360. 精度(テスト) = 0.9666666666666667
#                 : 380. 誤差(テスト) = 0.1096367303339302
#                 : 380. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.12605880197548291
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 420. 誤差(テスト) = 0.10995232529503368
#                 : 420. 精度(テスト) = 0.9666666666666667
#                 : 440. 誤差(テスト) = 0.10856100026150066
#                 : 440. 精度(テスト) = 0.9666666666666667
#                 : 460. 誤差(テスト) = 0.11449312664265386
#                 : 460. 精度(テスト) = 0.9666666666666667
#                 : 480. 誤差(テスト) = 0.10966395182525361
#                 : 480. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.11405407559272233
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 520. 誤差(テスト) = 0.10800368650868244
#                 : 520. 精度(テスト) = 0.9666666666666667
#                 : 540. 誤差(テスト) = 0.10824755728347799
#                 : 540. 精度(テスト) = 0.9666666666666667
#                 : 560. 誤差(テスト) = 0.10501263034463829
#                 : 560. 精度(テスト) = 0.9666666666666667
#                 : 580. 誤差(テスト) = 0.11211374080417412
#                 : 580. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.1063429637736911
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 620. 誤差(テスト) = 0.1138120092535465
#                 : 620. 精度(テスト) = 0.9666666666666667
#                 : 640. 誤差(テスト) = 0.11628660171433249
#                 : 640. 精度(テスト) = 0.9666666666666667
#                 : 660. 誤差(テスト) = 0.11002675613273209
#                 : 660. 精度(テスト) = 0.9666666666666667
#                 : 680. 誤差(テスト) = 0.11401895083645769
#                 : 680. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.11335019363575068
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 720. 誤差(テスト) = 0.1084145431104395
#                 : 720. 精度(テスト) = 0.9666666666666667
#                 : 740. 誤差(テスト) = 0.10677616691172923
#                 : 740. 精度(テスト) = 0.9666666666666667
#                 : 760. 誤差(テスト) = 0.12331383950045251
#                 : 760. 精度(テスト) = 0.9666666666666667
#                 : 780. 誤差(テスト) = 0.11290072074241018
#                 : 780. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.10851490913102024
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.11917220353549032
#                 : 820. 精度(テスト) = 0.9666666666666667
#                 : 840. 誤差(テスト) = 0.11497342482535558
#                 : 840. 精度(テスト) = 0.9666666666666667
#                 : 860. 誤差(テスト) = 0.11592515682063625
#                 : 860. 精度(テスト) = 0.9666666666666667
#                 : 880. 誤差(テスト) = 0.11410539075969932
#                 : 880. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.10644295524298966
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 920. 誤差(テスト) = 0.1066958388084445
#                 : 920. 精度(テスト) = 0.9666666666666667
#                 : 940. 誤差(テスト) = 0.12022498899635461
#                 : 940. 精度(テスト) = 0.9666666666666667
#                 : 960. 誤差(テスト) = 0.1317852547791793
#                 : 960. 精度(テスト) = 0.9666666666666667
#                 : 980. 誤差(テスト) = 0.13830999042816502
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.10817974867644606
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop4 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.09013665940923647
#                 : 20. 精度(テスト) = 1.0
#                 : 40. 誤差(テスト) = 0.0731452930499676
#                 : 40. 精度(テスト) = 1.0
#                 : 60. 誤差(テスト) = 0.058170217957962324
#                 : 60. 精度(テスト) = 1.0
#                 : 80. 誤差(テスト) = 0.06437316060458385
#                 : 80. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.04852631888562443
#                 : 100. 精度(テスト) = 1.0
#                 : 120. 誤差(テスト) = 0.049462487003352124
#                 : 120. 精度(テスト) = 1.0
#                 : 140. 誤差(テスト) = 0.07320137345450012
#                 : 140. 精度(テスト) = 1.0
#                 : 160. 誤差(テスト) = 0.06262789415563397
#                 : 160. 精度(テスト) = 1.0
#                 : 180. 誤差(テスト) = 0.06863448607393395
#                 : 180. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.05693582061667456
#                 : 200. 精度(テスト) = 1.0
#                 : 220. 誤差(テスト) = 0.05694539527054643
#                 : 220. 精度(テスト) = 1.0
#                 : 240. 誤差(テスト) = 0.056094795957443364
#                 : 240. 精度(テスト) = 1.0
#                 : 260. 誤差(テスト) = 0.0537918586782581
#                 : 260. 精度(テスト) = 1.0
#                 : 280. 誤差(テスト) = 0.06542913898522028
#                 : 280. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.053675718016958064
#                 : 300. 精度(テスト) = 1.0
#                 : 320. 誤差(テスト) = 0.06580372124514146
#                 : 320. 精度(テスト) = 1.0
#                 : 340. 誤差(テスト) = 0.056761496264939044
#                 : 340. 精度(テスト) = 1.0
#                 : 360. 誤差(テスト) = 0.05626870104576653
#                 : 360. 精度(テスト) = 1.0
#                 : 380. 誤差(テスト) = 0.063675977138711
#                 : 380. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.09060329246768896
#                 : 400. 精度(テスト) = 1.0
#                 : 420. 誤差(テスト) = 0.05691254401244355
#                 : 420. 精度(テスト) = 1.0
#                 : 440. 誤差(テスト) = 0.046241746512100786
#                 : 440. 精度(テスト) = 1.0
#                 : 460. 誤差(テスト) = 0.05522775984845428
#                 : 460. 精度(テスト) = 1.0
#                 : 480. 誤差(テスト) = 0.08980250666201409
#                 : 480. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.06991458546101594
#                 : 500. 精度(テスト) = 1.0
#                 : 520. 誤差(テスト) = 0.08266336556439695
#                 : 520. 精度(テスト) = 1.0
#                 : 540. 誤差(テスト) = 0.09956583400738278
#                 : 540. 精度(テスト) = 0.9666666666666667
#                 : 560. 誤差(テスト) = 0.0771858924940176
#                 : 560. 精度(テスト) = 1.0
#                 : 580. 誤差(テスト) = 0.08133851253695602
#                 : 580. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.059558724728314576
#                 : 600. 精度(テスト) = 1.0
#                 : 620. 誤差(テスト) = 0.04606136835426041
#                 : 620. 精度(テスト) = 1.0
#                 : 640. 誤差(テスト) = 0.08878619513135613
#                 : 640. 精度(テスト) = 1.0
#                 : 660. 誤差(テスト) = 0.07060241462723131
#                 : 660. 精度(テスト) = 1.0
#                 : 680. 誤差(テスト) = 0.08720174773138162
#                 : 680. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.0773448323080375
#                 : 700. 精度(テスト) = 1.0
#                 : 720. 誤差(テスト) = 0.05064636386374759
#                 : 720. 精度(テスト) = 1.0
#                 : 740. 誤差(テスト) = 0.06924877323012261
#                 : 740. 精度(テスト) = 1.0
#                 : 760. 誤差(テスト) = 0.049025835059351
#                 : 760. 精度(テスト) = 1.0
#                 : 780. 誤差(テスト) = 0.08269325807784456
#                 : 780. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.11111811625196473
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.06427830295540768
#                 : 820. 精度(テスト) = 1.0
#                 : 840. 誤差(テスト) = 0.07384383949134934
#                 : 840. 精度(テスト) = 1.0
#                 : 860. 誤差(テスト) = 0.09731929157614458
#                 : 860. 精度(テスト) = 0.9666666666666667
#                 : 880. 誤差(テスト) = 0.06756197166442941
#                 : 880. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.06826191606687057
#                 : 900. 精度(テスト) = 1.0
#                 : 920. 誤差(テスト) = 0.06630235189056922
#                 : 920. 精度(テスト) = 1.0
#                 : 940. 誤差(テスト) = 0.08405967595077232
#                 : 940. 精度(テスト) = 1.0
#                 : 960. 誤差(テスト) = 0.048680622455048186
#                 : 960. 精度(テスト) = 1.0
#                 : 980. 誤差(テスト) = 0.04601843564535305
#                 : 980. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.06926565458594101
#                 : 1000. 精度(テスト) = 1.0
# Loop5 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.10450519204706009
#                 : 20. 精度(テスト) = 0.9666666666666667
#                 : 40. 誤差(テスト) = 0.10684029870776525
#                 : 40. 精度(テスト) = 0.9666666666666667
#                 : 60. 誤差(テスト) = 0.1033707435515732
#                 : 60. 精度(テスト) = 0.9666666666666667
#                 : 80. 誤差(テスト) = 0.10524338492256695
#                 : 80. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.10790702248649947
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 120. 誤差(テスト) = 0.10990306795243068
#                 : 120. 精度(テスト) = 0.9666666666666667
#                 : 140. 誤差(テスト) = 0.1219941514034796
#                 : 140. 精度(テスト) = 0.9666666666666667
#                 : 160. 誤差(テスト) = 0.11625662480762974
#                 : 160. 精度(テスト) = 0.9666666666666667
#                 : 180. 誤差(テスト) = 0.1171459170714053
#                 : 180. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.1115259031503913
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 220. 誤差(テスト) = 0.10888390869323201
#                 : 220. 精度(テスト) = 0.9666666666666667
#                 : 240. 誤差(テスト) = 0.10925543763931114
#                 : 240. 精度(テスト) = 0.9666666666666667
#                 : 260. 誤差(テスト) = 0.10699479299639963
#                 : 260. 精度(テスト) = 0.9666666666666667
#                 : 280. 誤差(テスト) = 0.10460005251225976
#                 : 280. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.12384570292179516
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 320. 誤差(テスト) = 0.1196030337758044
#                 : 320. 精度(テスト) = 0.9666666666666667
#                 : 340. 誤差(テスト) = 0.12151475506972788
#                 : 340. 精度(テスト) = 0.9666666666666667
#                 : 360. 誤差(テスト) = 0.1242944827929497
#                 : 360. 精度(テスト) = 0.9666666666666667
#                 : 380. 誤差(テスト) = 0.12616387299182097
#                 : 380. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.11379096298200223
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 420. 誤差(テスト) = 0.11742710654948141
#                 : 420. 精度(テスト) = 0.9666666666666667
#                 : 440. 誤差(テスト) = 0.1081403023467822
#                 : 440. 精度(テスト) = 0.9666666666666667
#                 : 460. 誤差(テスト) = 0.10614738449212728
#                 : 460. 精度(テスト) = 0.9666666666666667
#                 : 480. 誤差(テスト) = 0.11130908032803426
#                 : 480. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.10968907540979056
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 520. 誤差(テスト) = 0.11826150815084877
#                 : 520. 精度(テスト) = 0.9666666666666667
#                 : 540. 誤差(テスト) = 0.1134352845122783
#                 : 540. 精度(テスト) = 0.9666666666666667
#                 : 560. 誤差(テスト) = 0.11475431103202882
#                 : 560. 精度(テスト) = 0.9666666666666667
#                 : 580. 誤差(テスト) = 0.10790623547536424
#                 : 580. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.10781248927770869
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 620. 誤差(テスト) = 0.1088748930846027
#                 : 620. 精度(テスト) = 0.9666666666666667
#                 : 640. 誤差(テスト) = 0.10922038847577978
#                 : 640. 精度(テスト) = 0.9666666666666667
#                 : 660. 誤差(テスト) = 0.11432421316843425
#                 : 660. 精度(テスト) = 0.9666666666666667
#                 : 680. 誤差(テスト) = 0.11634396554357387
#                 : 680. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.11296724686293332
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 720. 誤差(テスト) = 0.11356494874371831
#                 : 720. 精度(テスト) = 0.9666666666666667
#                 : 740. 誤差(テスト) = 0.10933020933058724
#                 : 740. 精度(テスト) = 0.9666666666666667
#                 : 760. 誤差(テスト) = 0.11905674862713912
#                 : 760. 精度(テスト) = 0.9666666666666667
#                 : 780. 誤差(テスト) = 0.11162514638905248
#                 : 780. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.11539670017944585
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.12365687439415285
#                 : 820. 精度(テスト) = 0.9666666666666667
#                 : 840. 誤差(テスト) = 0.10904915030069876
#                 : 840. 精度(テスト) = 0.9666666666666667
#                 : 860. 誤差(テスト) = 0.11308854986795897
#                 : 860. 精度(テスト) = 0.9666666666666667
#                 : 880. 誤差(テスト) = 0.1197469797225186
#                 : 880. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.10992909489688754
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 920. 誤差(テスト) = 0.11066660839663549
#                 : 920. 精度(テスト) = 0.9666666666666667
#                 : 940. 誤差(テスト) = 0.10913015214051631
#                 : 940. 精度(テスト) = 0.9666666666666667
#                 : 960. 誤差(テスト) = 0.10791092163208178
#                 : 960. 精度(テスト) = 0.9666666666666667
#                 : 980. 誤差(テスト) = 0.10861185342079734
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.10662595889392693
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop6 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.050065524914880775
#                 : 20. 精度(テスト) = 0.9666666666666667
#                 : 40. 誤差(テスト) = 0.07563157689036988
#                 : 40. 精度(テスト) = 0.9666666666666667
#                 : 60. 誤差(テスト) = 0.06292817053161218
#                 : 60. 精度(テスト) = 0.9666666666666667
#                 : 80. 誤差(テスト) = 0.03184973059864678
#                 : 80. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.056021638042749254
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 120. 誤差(テスト) = 0.044820526694098826
#                 : 120. 精度(テスト) = 1.0
#                 : 140. 誤差(テスト) = 0.052847171778403985
#                 : 140. 精度(テスト) = 0.9666666666666667
#                 : 160. 誤差(テスト) = 0.04410057147755421
#                 : 160. 精度(テスト) = 1.0
#                 : 180. 誤差(テスト) = 0.039425143618547064
#                 : 180. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.04391286623579757
#                 : 200. 精度(テスト) = 1.0
#                 : 220. 誤差(テスト) = 0.03836010255357673
#                 : 220. 精度(テスト) = 1.0
#                 : 240. 誤差(テスト) = 0.03006880291723696
#                 : 240. 精度(テスト) = 1.0
#                 : 260. 誤差(テスト) = 0.040414817489862045
#                 : 260. 精度(テスト) = 1.0
#                 : 280. 誤差(テスト) = 0.030066107878921947
#                 : 280. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.026838228484849083
#                 : 300. 精度(テスト) = 1.0
#                 : 320. 誤差(テスト) = 0.035277475404473776
#                 : 320. 精度(テスト) = 1.0
#                 : 340. 誤差(テスト) = 0.0420707539282268
#                 : 340. 精度(テスト) = 1.0
#                 : 360. 誤差(テスト) = 0.05338038305514836
#                 : 360. 精度(テスト) = 0.9666666666666667
#                 : 380. 誤差(テスト) = 0.05489566254625628
#                 : 380. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.07733218629262775
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 420. 誤差(テスト) = 0.04942680611136723
#                 : 420. 精度(テスト) = 0.9666666666666667
#                 : 440. 誤差(テスト) = 0.0480591494543965
#                 : 440. 精度(テスト) = 1.0
#                 : 460. 誤差(テスト) = 0.045141962741918756
#                 : 460. 精度(テスト) = 1.0
#                 : 480. 誤差(テスト) = 0.04773333720206836
#                 : 480. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.06288433495320377
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 520. 誤差(テスト) = 0.05359475623915556
#                 : 520. 精度(テスト) = 0.9666666666666667
#                 : 540. 誤差(テスト) = 0.042567070598744226
#                 : 540. 精度(テスト) = 1.0
#                 : 560. 誤差(テスト) = 0.054144254742222085
#                 : 560. 精度(テスト) = 0.9666666666666667
#                 : 580. 誤差(テスト) = 0.06141728715107215
#                 : 580. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.0432725213809525
#                 : 600. 精度(テスト) = 1.0
#                 : 620. 誤差(テスト) = 0.03505931720205073
#                 : 620. 精度(テスト) = 1.0
#                 : 640. 誤差(テスト) = 0.0381819877425855
#                 : 640. 精度(テスト) = 1.0
#                 : 660. 誤差(テスト) = 0.03838788465112233
#                 : 660. 精度(テスト) = 1.0
#                 : 680. 誤差(テスト) = 0.03534380113400782
#                 : 680. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.04029413231780817
#                 : 700. 精度(テスト) = 1.0
#                 : 720. 誤差(テスト) = 0.04818238028830138
#                 : 720. 精度(テスト) = 1.0
#                 : 740. 誤差(テスト) = 0.04260707951821097
#                 : 740. 精度(テスト) = 1.0
#                 : 760. 誤差(テスト) = 0.06089766760786362
#                 : 760. 精度(テスト) = 0.9666666666666667
#                 : 780. 誤差(テスト) = 0.056089453211843034
#                 : 780. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.05922220874699571
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.04634787345274139
#                 : 820. 精度(テスト) = 1.0
#                 : 840. 誤差(テスト) = 0.043536818844960926
#                 : 840. 精度(テスト) = 1.0
#                 : 860. 誤差(テスト) = 0.03949478807209235
#                 : 860. 精度(テスト) = 1.0
#                 : 880. 誤差(テスト) = 0.0424527108098343
#                 : 880. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.05949660741374392
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 920. 誤差(テスト) = 0.0421008892527592
#                 : 920. 精度(テスト) = 1.0
#                 : 940. 誤差(テスト) = 0.03632804600587095
#                 : 940. 精度(テスト) = 1.0
#                 : 960. 誤差(テスト) = 0.0467519487082024
#                 : 960. 精度(テスト) = 1.0
#                 : 980. 誤差(テスト) = 0.049063437103710104
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.04409722230711136
#                 : 1000. 精度(テスト) = 1.0
# Loop7 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.047439535458072966
#                 : 20. 精度(テスト) = 1.0
#                 : 40. 誤差(テスト) = 0.04289652451921409
#                 : 40. 精度(テスト) = 1.0
#                 : 60. 誤差(テスト) = 0.04355786876254804
#                 : 60. 精度(テスト) = 1.0
#                 : 80. 誤差(テスト) = 0.06507492361148845
#                 : 80. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.04615210859167844
#                 : 100. 精度(テスト) = 1.0
#                 : 120. 誤差(テスト) = 0.04766965007413802
#                 : 120. 精度(テスト) = 1.0
#                 : 140. 誤差(テスト) = 0.046448911405811075
#                 : 140. 精度(テスト) = 1.0
#                 : 160. 誤差(テスト) = 0.05187602656123176
#                 : 160. 精度(テスト) = 1.0
#                 : 180. 誤差(テスト) = 0.04940510178707012
#                 : 180. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.04987201432300368
#                 : 200. 精度(テスト) = 1.0
#                 : 220. 誤差(テスト) = 0.04948896284661733
#                 : 220. 精度(テスト) = 1.0
#                 : 240. 誤差(テスト) = 0.04981374977600831
#                 : 240. 精度(テスト) = 1.0
#                 : 260. 誤差(テスト) = 0.049001296622770966
#                 : 260. 精度(テスト) = 1.0
#                 : 280. 誤差(テスト) = 0.04863925208172577
#                 : 280. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.05427020642833027
#                 : 300. 精度(テスト) = 1.0
#                 : 320. 誤差(テスト) = 0.056849551640962524
#                 : 320. 精度(テスト) = 1.0
#                 : 340. 誤差(テスト) = 0.04944709175012451
#                 : 340. 精度(テスト) = 1.0
#                 : 360. 誤差(テスト) = 0.04755979530655915
#                 : 360. 精度(テスト) = 1.0
#                 : 380. 誤差(テスト) = 0.05773337873990248
#                 : 380. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.06348677861600724
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 420. 誤差(テスト) = 0.05182329393661126
#                 : 420. 精度(テスト) = 1.0
#                 : 440. 誤差(テスト) = 0.047436702555558465
#                 : 440. 精度(テスト) = 1.0
#                 : 460. 誤差(テスト) = 0.05949456619281566
#                 : 460. 精度(テスト) = 1.0
#                 : 480. 誤差(テスト) = 0.046459425266011205
#                 : 480. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.04401670073817184
#                 : 500. 精度(テスト) = 1.0
#                 : 520. 誤差(テスト) = 0.06339249474104562
#                 : 520. 精度(テスト) = 0.9666666666666667
#                 : 540. 誤差(テスト) = 0.04463441782847369
#                 : 540. 精度(テスト) = 1.0
#                 : 560. 誤差(テスト) = 0.04561801347927276
#                 : 560. 精度(テスト) = 1.0
#                 : 580. 誤差(テスト) = 0.05144356199277218
#                 : 580. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.04604550913987504
#                 : 600. 精度(テスト) = 1.0
#                 : 620. 誤差(テスト) = 0.047059570132623386
#                 : 620. 精度(テスト) = 1.0
#                 : 640. 誤差(テスト) = 0.05131081089152874
#                 : 640. 精度(テスト) = 1.0
#                 : 660. 誤差(テスト) = 0.0630883719100313
#                 : 660. 精度(テスト) = 1.0
#                 : 680. 誤差(テスト) = 0.05590267511229912
#                 : 680. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.05046269617004521
#                 : 700. 精度(テスト) = 1.0
#                 : 720. 誤差(テスト) = 0.052334691197695286
#                 : 720. 精度(テスト) = 1.0
#                 : 740. 誤差(テスト) = 0.053423374734227244
#                 : 740. 精度(テスト) = 1.0
#                 : 760. 誤差(テスト) = 0.05923710493791147
#                 : 760. 精度(テスト) = 1.0
#                 : 780. 誤差(テスト) = 0.05281968257594601
#                 : 780. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.047650545811601726
#                 : 800. 精度(テスト) = 1.0
#                 : 820. 誤差(テスト) = 0.05025053196576812
#                 : 820. 精度(テスト) = 1.0
#                 : 840. 誤差(テスト) = 0.05103122831326293
#                 : 840. 精度(テスト) = 1.0
#                 : 860. 誤差(テスト) = 0.058114457094466505
#                 : 860. 精度(テスト) = 1.0
#                 : 880. 誤差(テスト) = 0.05258031159143069
#                 : 880. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.051302439286463164
#                 : 900. 精度(テスト) = 1.0
#                 : 920. 誤差(テスト) = 0.04727023077570578
#                 : 920. 精度(テスト) = 1.0
#                 : 940. 誤差(テスト) = 0.0585344881344394
#                 : 940. 精度(テスト) = 1.0
#                 : 960. 誤差(テスト) = 0.05945198077511864
#                 : 960. 精度(テスト) = 1.0
#                 : 980. 誤差(テスト) = 0.07465577691385386
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.05211703424616137
#                 : 1000. 精度(テスト) = 1.0
# Loop8 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.04058612135782925
#                 : 20. 精度(テスト) = 1.0
#                 : 40. 誤差(テスト) = 0.04503419774253954
#                 : 40. 精度(テスト) = 1.0
#                 : 60. 誤差(テスト) = 0.037957442392151104
#                 : 60. 精度(テスト) = 1.0
#                 : 80. 誤差(テスト) = 0.03744150539521054
#                 : 80. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.03587484107239412
#                 : 100. 精度(テスト) = 1.0
#                 : 120. 誤差(テスト) = 0.03928516101030541
#                 : 120. 精度(テスト) = 1.0
#                 : 140. 誤差(テスト) = 0.036215256697021386
#                 : 140. 精度(テスト) = 1.0
#                 : 160. 誤差(テスト) = 0.037511040133219445
#                 : 160. 精度(テスト) = 1.0
#                 : 180. 誤差(テスト) = 0.042446607303591434
#                 : 180. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.03645076116403271
#                 : 200. 精度(テスト) = 1.0
#                 : 220. 誤差(テスト) = 0.0388888534339484
#                 : 220. 精度(テスト) = 1.0
#                 : 240. 誤差(テスト) = 0.04344142802327613
#                 : 240. 精度(テスト) = 1.0
#                 : 260. 誤差(テスト) = 0.03968411302886479
#                 : 260. 精度(テスト) = 1.0
#                 : 280. 誤差(テスト) = 0.037710870102782554
#                 : 280. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.03797647925276489
#                 : 300. 精度(テスト) = 1.0
#                 : 320. 誤差(テスト) = 0.037211382215853246
#                 : 320. 精度(テスト) = 1.0
#                 : 340. 誤差(テスト) = 0.03849128924951003
#                 : 340. 精度(テスト) = 1.0
#                 : 360. 誤差(テスト) = 0.039274752764657
#                 : 360. 精度(テスト) = 1.0
#                 : 380. 誤差(テスト) = 0.03984807898406949
#                 : 380. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.039804993782091534
#                 : 400. 精度(テスト) = 1.0
#                 : 420. 誤差(テスト) = 0.04031517047325859
#                 : 420. 精度(テスト) = 1.0
#                 : 440. 誤差(テスト) = 0.04064151481519775
#                 : 440. 精度(テスト) = 1.0
#                 : 460. 誤差(テスト) = 0.03807764092089417
#                 : 460. 精度(テスト) = 1.0
#                 : 480. 誤差(テスト) = 0.04580494424668503
#                 : 480. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.04317124153037674
#                 : 500. 精度(テスト) = 1.0
#                 : 520. 誤差(テスト) = 0.03632870793916227
#                 : 520. 精度(テスト) = 1.0
#                 : 540. 誤差(テスト) = 0.04228126106794223
#                 : 540. 精度(テスト) = 1.0
#                 : 560. 誤差(テスト) = 0.04208506199832001
#                 : 560. 精度(テスト) = 1.0
#                 : 580. 誤差(テスト) = 0.03895878211241572
#                 : 580. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.04193577632962717
#                 : 600. 精度(テスト) = 1.0
#                 : 620. 誤差(テスト) = 0.04474418925215134
#                 : 620. 精度(テスト) = 1.0
#                 : 640. 誤差(テスト) = 0.03948606737849322
#                 : 640. 精度(テスト) = 1.0
#                 : 660. 誤差(テスト) = 0.05361713456077244
#                 : 660. 精度(テスト) = 1.0
#                 : 680. 誤差(テスト) = 0.044809506101860005
#                 : 680. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.039674330198726016
#                 : 700. 精度(テスト) = 1.0
#                 : 720. 誤差(テスト) = 0.03959415174132181
#                 : 720. 精度(テスト) = 1.0
#                 : 740. 誤差(テスト) = 0.0376822738885469
#                 : 740. 精度(テスト) = 1.0
#                 : 760. 誤差(テスト) = 0.03461618197855392
#                 : 760. 精度(テスト) = 1.0
#                 : 780. 誤差(テスト) = 0.04018020541529015
#                 : 780. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.03755777086606009
#                 : 800. 精度(テスト) = 1.0
#                 : 820. 誤差(テスト) = 0.036274202651121655
#                 : 820. 精度(テスト) = 1.0
#                 : 840. 誤差(テスト) = 0.04259882760503265
#                 : 840. 精度(テスト) = 1.0
#                 : 860. 誤差(テスト) = 0.04086538993730624
#                 : 860. 精度(テスト) = 1.0
#                 : 880. 誤差(テスト) = 0.04320373986292425
#                 : 880. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.038729410591930365
#                 : 900. 精度(テスト) = 1.0
#                 : 920. 誤差(テスト) = 0.03684171065981997
#                 : 920. 精度(テスト) = 1.0
#                 : 940. 誤差(テスト) = 0.03917332764213895
#                 : 940. 精度(テスト) = 1.0
#                 : 960. 誤差(テスト) = 0.038451751345337896
#                 : 960. 精度(テスト) = 1.0
#                 : 980. 誤差(テスト) = 0.03888310770712334
#                 : 980. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.04056443968925404
#                 : 1000. 精度(テスト) = 1.0
# Loop9 データ読み込み完了
#                 : 20. 誤差(テスト) = 0.059218098020875305
#                 : 20. 精度(テスト) = 0.9666666666666667
#                 : 40. 誤差(テスト) = 0.04310752497512963
#                 : 40. 精度(テスト) = 1.0
#                 : 60. 誤差(テスト) = 0.06145457954740108
#                 : 60. 精度(テスト) = 0.9666666666666667
#                 : 80. 誤差(テスト) = 0.10893754718736497
#                 : 80. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.10464799747620578
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 120. 誤差(テスト) = 0.04812416565901579
#                 : 120. 精度(テスト) = 1.0
#                 : 140. 誤差(テスト) = 0.04261961712746443
#                 : 140. 精度(テスト) = 1.0
#                 : 160. 誤差(テスト) = 0.04057232545921937
#                 : 160. 精度(テスト) = 1.0
#                 : 180. 誤差(テスト) = 0.04347917505817085
#                 : 180. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.048487028800052484
#                 : 200. 精度(テスト) = 1.0
#                 : 220. 誤差(テスト) = 0.06756022694846248
#                 : 220. 精度(テスト) = 0.9666666666666667
#                 : 240. 誤差(テスト) = 0.05772785566443314
#                 : 240. 精度(テスト) = 1.0
#                 : 260. 誤差(テスト) = 0.06020674527478582
#                 : 260. 精度(テスト) = 1.0
#                 : 280. 誤差(テスト) = 0.044797354623253134
#                 : 280. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.06428341694631655
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 320. 誤差(テスト) = 0.04952061792796232
#                 : 320. 精度(テスト) = 1.0
#                 : 340. 誤差(テスト) = 0.09529707222937334
#                 : 340. 精度(テスト) = 0.9666666666666667
#                 : 360. 誤差(テスト) = 0.07770933407419703
#                 : 360. 精度(テスト) = 0.9666666666666667
#                 : 380. 誤差(テスト) = 0.05679287957247677
#                 : 380. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.060204868429587485
#                 : 400. 精度(テスト) = 1.0
#                 : 420. 誤差(テスト) = 0.04751646097324049
#                 : 420. 精度(テスト) = 1.0
#                 : 440. 誤差(テスト) = 0.03525962975205444
#                 : 440. 精度(テスト) = 1.0
#                 : 460. 誤差(テスト) = 0.05431449378706624
#                 : 460. 精度(テスト) = 1.0
#                 : 480. 誤差(テスト) = 0.05739283782408427
#                 : 480. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.049114173847941735
#                 : 500. 精度(テスト) = 1.0
#                 : 520. 誤差(テスト) = 0.0466959572830672
#                 : 520. 精度(テスト) = 1.0
#                 : 540. 誤差(テスト) = 0.039650648521160035
#                 : 540. 精度(テスト) = 1.0
#                 : 560. 誤差(テスト) = 0.03705354992370908
#                 : 560. 精度(テスト) = 1.0
#                 : 580. 誤差(テスト) = 0.0571908111423129
#                 : 580. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.055968013174477374
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 620. 誤差(テスト) = 0.03882410756455309
#                 : 620. 精度(テスト) = 1.0
#                 : 640. 誤差(テスト) = 0.05015648749399742
#                 : 640. 精度(テスト) = 1.0
#                 : 660. 誤差(テスト) = 0.05117490528867993
#                 : 660. 精度(テスト) = 1.0
#                 : 680. 誤差(テスト) = 0.04836248818366854
#                 : 680. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.0631877055383904
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 720. 誤差(テスト) = 0.04881094998512299
#                 : 720. 精度(テスト) = 1.0
#                 : 740. 誤差(テスト) = 0.052547760020572175
#                 : 740. 精度(テスト) = 1.0
#                 : 760. 誤差(テスト) = 0.04028296751523825
#                 : 760. 精度(テスト) = 1.0
#                 : 780. 誤差(テスト) = 0.04391060236339823
#                 : 780. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.055689370936817036
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 820. 誤差(テスト) = 0.07095423026600815
#                 : 820. 精度(テスト) = 0.9666666666666667
#                 : 840. 誤差(テスト) = 0.05640453394614346
#                 : 840. 精度(テスト) = 1.0
#                 : 860. 誤差(テスト) = 0.045388623946556766
#                 : 860. 精度(テスト) = 1.0
#                 : 880. 誤差(テスト) = 0.07650468837793294
#                 : 880. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.045555617892322466
#                 : 900. 精度(テスト) = 1.0
#                 : 920. 誤差(テスト) = 0.0477600095387773
#                 : 920. 精度(テスト) = 1.0
#                 : 940. 誤差(テスト) = 0.04196306875694896
#                 : 940. 精度(テスト) = 1.0
#                 : 960. 誤差(テスト) = 0.047035891847534185
#                 : 960. 精度(テスト) = 1.0
#                 : 980. 誤差(テスト) = 0.05395881765758
#                 : 980. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.057398216989305646
#                 : 1000. 精度(テスト) = 0.9666666666666667

# %%
# グラフの表示
plt.ylim(0, 1.05)
plt.axhline(y=1, linewidth=1, color='lightgray')
for i in range(tests_num+1):
    x = iters_num * i
    plt.axvline(x, linewidth=1, color='lightgray')

lists = range(0, iters_num*tests_num, plot_interval)
plt.plot(lists, losses, label="loss - training set")
plt.plot(lists, losses_test,  label="loss - test set")
plt.plot(lists, accuracies, label="acc - training set")
plt.plot(lists, accuracies_test, label="acc - test set")
plt.title("loss/accuracy")
plt.xlabel("iteration")
plt.ylabel("loss/accuracy")
plt.legend(loc='best',
           bbox_to_anchor=(1.05, 0.5, 0.5, .100), 
           borderaxespad=0.,)

plt.savefig("output.jpg", bbox_inches='tight')
plt.show()
