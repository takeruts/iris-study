# %% [markdown]
# # IRIS Classification

# %% [markdown]
# #### Aug 22, 2018
# #### Takeru Tsuchiya

# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import pylab
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
debug = False

# %%
iris = datasets.load_iris()
x_vals = np.array([x[0:4] for x in iris.data])
y_vals = np.array([y for y in iris.target])

# Transform to Onehot
y_vals = np.array(y_vals).reshape(1, -1).transpose()
encoder = OneHotEncoder(n_values=max(y_vals)+1)
y_vals = encoder.fit_transform(y_vals).toarray()

# %%
# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 4
#中間層サイズ
hidden_layer1_size = 64
hidden_layer2_size = 128
hidden_layer3_size = 128

num_hidden_layers = 3
#出力層サイズ
output_layer_size = 3
# 訓練データ、テストデータの抽出繰り返し数
tests_num = 10
# バッチ処理繰り返し数
iters_num = 1000
# ミニバッチサイズ
batch_size = 40
# 学習率
learning_rate=0.001
# 描写頻度
plot_interval= 50

# Adam parameters
beta1 = 0.9
beta2 = 0.999

# 正則化強度設定 ======================================
weight_decay_lambda = 0.01
# =================================================

# ドリップアウト
dropout_ratio = 0.4

# %%
# ReLU関数
def relu(x):
    return np.maximum(0, x)
# 出力層の活性化関数
# ソフトマックス関数
def softmax(x):
    if x.ndim == 2:
        x = x.T
        x = x - np.max(x, axis=0)
        y = np.exp(x) / np.sum(np.exp(x), axis=0)
        return y.T

    x = x - np.max(x) # オーバーフロー対策
    return np.exp(x) / np.sum(np.exp(x))

# ReLU関数の導関数
def d_relu(x):
    return np.where( x > 0, 1, 0)
# ソフトマックスとクロスエントロピーの複合導関数
def d_softmax_with_loss(d, y):
    batch_size = d.shape[0]
    if d.size == y.size: # 教師データがone-hot-vectorの場合
        dx = (y - d) / batch_size
    else:
        dx = y.copy()
        dx[np.arange(batch_size), d] -= 1
        dx = dx / batch_size
    return dx

def cross_entropy_error(d, y):
    y_max = np.argmax(y, axis=1)
    d_max = np.argmax(d, axis=1)

    batch_size = y_max.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), d_max] + 1e-7)) / batch_size

def accuracy(d, y):
    y_max = np.argmax(y, axis=1)
    d_max = np.argmax(d, axis=1)
    
    batch_size = float(y_max.shape[0])
    return np.sum(y_max == d_max) / batch_size

# %%
# 初期設定
def init_network():
    network = {} 
    # Heの初期値    
    network['W1'] = np.random.randn(input_layer_size, hidden_layer1_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    network['W2'] = np.random.randn(hidden_layer1_size, hidden_layer2_size) / np.sqrt(hidden_layer1_size) * np.sqrt(2)
    network['W3'] = np.random.randn(hidden_layer2_size, hidden_layer3_size) / np.sqrt(hidden_layer2_size) * np.sqrt(2)
    network['W4'] = np.random.randn(hidden_layer3_size, output_layer_size) / np.sqrt(hidden_layer3_size) * np.sqrt(2)

    network['b1'] = np.zeros(hidden_layer1_size)
    network['b2'] = np.zeros(hidden_layer2_size)
    network['b3'] = np.zeros(hidden_layer3_size)
    network['b4'] = np.zeros(output_layer_size)

    return network

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask

# %%
# 順伝播
def forward(network, x, train_flg):
    W = {}
    dropout = {}
    W1, W2, W3, W4 = network['W1'], network['W2'], network['W3'], network['W4']
    b1, b2, b3, b4  = network['b1'], network['b2'], network['b3'], network['b4']

    for idx in range(num_hidden_layers):
        dropout['u' + str(idx+1)] = Dropout(dropout_ratio)
        
    # 1st Layer
    u1 = np.dot(x, W1) + b1
    u1 = dropout['u1'].forward(u1, train_flg=train_flg)
    z1 = relu(u1)
    # 2nd Layer
    u2 = np.dot(z1, W2) + b2
    u2 = dropout['u2'].forward(u2, train_flg=train_flg)
    z2 = relu(u2)
    #3rd Layer
    u3 = np.dot(z2, W3) + b3
    u3 = dropout['u3'].forward(u3, train_flg=train_flg)
    z3 = relu(u3)
    #4th Layer
    u4 = np.dot(z3, W4) + b4
    y  = softmax(u4)

    return z1, z2, z3, y, dropout

# %%
# 誤差逆伝播
def backward(x, d, z1, z2, z3, y, dropout):
    grad = {}
    
    W1, W2, W3, W4 = network['W1'], network['W2'], network['W3'], network['W4']
    b1, b2, b3, b4 = network['b1'], network['b2'], network['b3'], network['b4']
    # 出力層でのデルタ
    delta4 = d_softmax_with_loss(d, y)
    grad['b4'] = np.sum(delta4, axis=0)
    grad['W4'] = np.dot(z3.T, delta4) + weight_decay_lambda * W4

    delta3 = np.dot(delta4, W4.T) * d_relu(z3)
    delta3 = dropout['u3'].backward(delta3)
    grad['b3'] = np.sum(delta3, axis=0)
    grad['W3'] = np.dot(z2.T, delta3) + weight_decay_lambda * W3
    # 2層でのデルタ       
    delta2 = np.dot(delta3, W3.T) * d_relu(z2)
    delta2 = dropout['u2'].backward(delta2)
    grad['b2'] = np.sum(delta2, axis=0)
    grad['W2'] = np.dot(z1.T, delta2) + weight_decay_lambda * W2
    # 1層でのデルタ       
    delta1 = np.dot(delta2, W2.T) * d_relu(z1)
    delta1 = dropout['u1'].backward(delta1)
    grad['b1'] = np.sum(delta1, axis=0)
    grad['W1'] = np.dot(x.T, delta1) + weight_decay_lambda * W1

    return grad

# %%
# パラメータの初期化
network = init_network()

losses = []
losses_test = []
accuracies = []
accuracies_test = []

for loop in range(tests_num):
    x_train, x_test, d_train, d_test = train_test_split(x_vals, y_vals, test_size=0.2, random_state=None,)
    train_size = len(x_train)

    print("Loop" + str(loop) + " データ読み込み完了")
    if debug:
        print("x_train", x_train.shape)
        print("x_test", x_test.shape)
        print("d_train", d_train.shape)
        print("d_test", d_test.shape)

    for i in range(iters_num):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        d_batch = d_train[batch_mask]
        #d_batch = d_batch[:, np.newaxis]

        z1, z2, z3, y, dropout = forward(network, x_batch, train_flg=True)
        grad = backward(x_batch, d_batch, z1, z2, z3, y, dropout)

        #for Test
        z1_test, z2_test, z3_test, y_test, dropout = forward(network, x_test, train_flg=False)

        # Adam ====================================================
        if i == 0:
            m = {}
            v = {}

        learning_rate_t  = learning_rate * np.sqrt(1.0 - beta2 ** (i + 1)) / (1.0 - beta1 ** (i + 1))

        for key in ('W1', 'W2', 'W3','W4', 'b1', 'b2', 'b3', 'b4'):

            if i == 0:
                m[key] = np.zeros_like(network[key])
                v[key] = np.zeros_like(network[key])

            m[key] += (1 - beta1) * (grad[key] - m[key])
            v[key] += (1 - beta2) * (grad[key] ** 2 - v[key])            

            network[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)


        # =========================================================

        #     print('loss',functions.least_square(d_batch, y))
        if (i + 1) % plot_interval == 0:
            loss = cross_entropy_error(d_batch, y)
            losses.append(loss)
            acc = accuracy(d_batch, y)
            accuracies.append(acc)

            loss_test = cross_entropy_error(d_test, y_test)
            losses_test.append(loss_test)
            acc_test = accuracy(d_test, y_test)
            accuracies_test.append(acc_test)

            print('                : ' + str(i+1) + '. 誤差(テスト) = ' + str(loss_test))
            print('                : ' + str(i+1) + '. 精度(テスト) = ' + str(acc_test))
# Out:
# Loop0 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.8890779292523494
#                 : 50. 精度(テスト) = 0.36666666666666664
#                 : 100. 誤差(テスト) = 0.5791858738184616
#                 : 100. 精度(テスト) = 0.7333333333333333
#                 : 150. 誤差(テスト) = 0.4609136787136829
#                 : 150. 精度(テスト) = 0.7666666666666667
#                 : 200. 誤差(テスト) = 0.40991199586458654
#                 : 200. 精度(テスト) = 0.7666666666666667
#                 : 250. 誤差(テスト) = 0.39166324458970697
#                 : 250. 精度(テスト) = 0.7333333333333333
#                 : 300. 誤差(テスト) = 0.3714937945055821
#                 : 300. 精度(テスト) = 0.7666666666666667
#                 : 350. 誤差(テスト) = 0.3582065746694065
#                 : 350. 精度(テスト) = 0.7666666666666667
#                 : 400. 誤差(テスト) = 0.3275885810671755
#                 : 400. 精度(テスト) = 0.8
#                 : 450. 誤差(テスト) = 0.2942365960132297
#                 : 450. 精度(テスト) = 0.9
#                 : 500. 誤差(テスト) = 0.2554937372989997
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 550. 誤差(テスト) = 0.2237749322720531
#                 : 550. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.19628682764723265
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 650. 誤差(テスト) = 0.17855917294622753
#                 : 650. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.1600562609408372
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 750. 誤差(テスト) = 0.15800392054712695
#                 : 750. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.14753256017942723
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 850. 誤差(テスト) = 0.14137937986091928
#                 : 850. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.13870512768354232
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 950. 誤差(テスト) = 0.13073909795613234
#                 : 950. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.13606044738445291
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop1 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.08398516559255603
#                 : 50. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.07494207032801319
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 150. 誤差(テスト) = 0.07544937817862718
#                 : 150. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.07903458303320786
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 250. 誤差(テスト) = 0.07030646750948352
#                 : 250. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.06997233466697142
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 350. 誤差(テスト) = 0.07092793849695106
#                 : 350. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.0706295546360728
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 450. 誤差(テスト) = 0.06678243502484517
#                 : 450. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.08158866520015236
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 550. 誤差(テスト) = 0.06767697752065355
#                 : 550. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.07214403864786209
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 650. 誤差(テスト) = 0.06997748237694242
#                 : 650. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.07157625558888962
#                 : 700. 精度(テスト) = 1.0
#                 : 750. 誤差(テスト) = 0.076888984056626
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.080787121496405
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 850. 誤差(テスト) = 0.06449966484178712
#                 : 850. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.06663693924391312
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 950. 誤差(テスト) = 0.0781892898176624
#                 : 950. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.068552634784143
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop2 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.029522300305729863
#                 : 50. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.031104616334399208
#                 : 100. 精度(テスト) = 1.0
#                 : 150. 誤差(テスト) = 0.027585492856139468
#                 : 150. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.038222772914847436
#                 : 200. 精度(テスト) = 1.0
#                 : 250. 誤差(テスト) = 0.03142210673828398
#                 : 250. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.030040408600742894
#                 : 300. 精度(テスト) = 1.0
#                 : 350. 誤差(テスト) = 0.03172279213786599
#                 : 350. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.02919814633647399
#                 : 400. 精度(テスト) = 1.0
#                 : 450. 誤差(テスト) = 0.03119397514079726
#                 : 450. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.030662386816323266
#                 : 500. 精度(テスト) = 1.0
#                 : 550. 誤差(テスト) = 0.04021528915538602
#                 : 550. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.02836534279095563
#                 : 600. 精度(テスト) = 1.0
#                 : 650. 誤差(テスト) = 0.027582896453384954
#                 : 650. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.03731983860954135
#                 : 700. 精度(テスト) = 1.0
#                 : 750. 誤差(テスト) = 0.029788059155928772
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.03296509250290922
#                 : 800. 精度(テスト) = 1.0
#                 : 850. 誤差(テスト) = 0.028658445829015524
#                 : 850. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.030445977217387447
#                 : 900. 精度(テスト) = 1.0
#                 : 950. 誤差(テスト) = 0.03326078641281679
#                 : 950. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.030486038344684028
#                 : 1000. 精度(テスト) = 1.0
# Loop3 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.0691772677080677
#                 : 50. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.06773543435481741
#                 : 100. 精度(テスト) = 1.0
#                 : 150. 誤差(テスト) = 0.08183798785258913
#                 : 150. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.05901535602828283
#                 : 200. 精度(テスト) = 1.0
#                 : 250. 誤差(テスト) = 0.06400241833574284
#                 : 250. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.079866612455075
#                 : 300. 精度(テスト) = 1.0
#                 : 350. 誤差(テスト) = 0.06533483816305258
#                 : 350. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.06733172510848531
#                 : 400. 精度(テスト) = 1.0
#                 : 450. 誤差(テスト) = 0.061508421212886216
#                 : 450. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.06466036503249376
#                 : 500. 精度(テスト) = 1.0
#                 : 550. 誤差(テスト) = 0.05897974061734805
#                 : 550. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.06479421757981811
#                 : 600. 精度(テスト) = 1.0
#                 : 650. 誤差(テスト) = 0.0680736889843253
#                 : 650. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.09416867438154847
#                 : 700. 精度(テスト) = 1.0
#                 : 750. 誤差(テスト) = 0.06652976286311592
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.06276824592246714
#                 : 800. 精度(テスト) = 1.0
#                 : 850. 誤差(テスト) = 0.06764293923781683
#                 : 850. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.09167688959946362
#                 : 900. 精度(テスト) = 1.0
#                 : 950. 誤差(テスト) = 0.07208667241375827
#                 : 950. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.0698643381888734
#                 : 1000. 精度(テスト) = 1.0
# Loop4 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.04682023118020442
#                 : 50. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.043795732378568805
#                 : 100. 精度(テスト) = 1.0
#                 : 150. 誤差(テスト) = 0.04664916203575705
#                 : 150. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.051860148619507704
#                 : 200. 精度(テスト) = 1.0
#                 : 250. 誤差(テスト) = 0.04392286226831833
#                 : 250. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.04644646120357455
#                 : 300. 精度(テスト) = 1.0
#                 : 350. 誤差(テスト) = 0.0403128828725349
#                 : 350. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.04460330698782083
#                 : 400. 精度(テスト) = 1.0
#                 : 450. 誤差(テスト) = 0.05020611938251369
#                 : 450. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.042090961573514364
#                 : 500. 精度(テスト) = 1.0
#                 : 550. 誤差(テスト) = 0.0496693452390166
#                 : 550. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.045708252753649606
#                 : 600. 精度(テスト) = 1.0
#                 : 650. 誤差(テスト) = 0.04622069067302724
#                 : 650. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.045269067239983744
#                 : 700. 精度(テスト) = 1.0
#                 : 750. 誤差(テスト) = 0.049159861720210016
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.057925321451339336
#                 : 800. 精度(テスト) = 1.0
#                 : 850. 誤差(テスト) = 0.04604528867339907
#                 : 850. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.04473012399534311
#                 : 900. 精度(テスト) = 1.0
#                 : 950. 誤差(テスト) = 0.07436153672930511
#                 : 950. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.035622454642692085
#                 : 1000. 精度(テスト) = 1.0
# Loop5 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.11599566461926901
#                 : 50. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.10813736055935426
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 150. 誤差(テスト) = 0.11573079557597864
#                 : 150. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.10548628242398415
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 250. 誤差(テスト) = 0.11271520416835523
#                 : 250. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.11313911835842463
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 350. 誤差(テスト) = 0.11008247719157356
#                 : 350. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.11556123744818442
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 450. 誤差(テスト) = 0.10421327460724909
#                 : 450. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.11186413794900801
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 550. 誤差(テスト) = 0.12452182554719181
#                 : 550. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.13661007175240103
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 650. 誤差(テスト) = 0.10615424143628426
#                 : 650. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.10496120929615946
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 750. 誤差(テスト) = 0.1076366606232427
#                 : 750. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.10992572064941832
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 850. 誤差(テスト) = 0.10987649189684599
#                 : 850. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.10240816029483485
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 950. 誤差(テスト) = 0.10289063909007415
#                 : 950. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.109541997891494
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop6 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.14304032461031765
#                 : 50. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.12582623617875502
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 150. 誤差(テスト) = 0.12652016775442293
#                 : 150. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.12768724880555304
#                 : 200. 精度(テスト) = 0.9666666666666667
#                 : 250. 誤差(テスト) = 0.1288025094789696
#                 : 250. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.12888617633149776
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 350. 誤差(テスト) = 0.1303378205484668
#                 : 350. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.12933373370780735
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 450. 誤差(テスト) = 0.12771584495106253
#                 : 450. 精度(テスト) = 0.9666666666666667
#                 : 500. 誤差(テスト) = 0.13148931066684574
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 550. 誤差(テスト) = 0.131121692832375
#                 : 550. 精度(テスト) = 0.9666666666666667
#                 : 600. 誤差(テスト) = 0.1335842733658468
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 650. 誤差(テスト) = 0.12808007033974136
#                 : 650. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.13775875010571076
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 750. 誤差(テスト) = 0.1270231859137866
#                 : 750. 精度(テスト) = 0.9666666666666667
#                 : 800. 誤差(テスト) = 0.12462503257465496
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 850. 誤差(テスト) = 0.1362994415046724
#                 : 850. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.1229182103791978
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 950. 誤差(テスト) = 0.1316885809447707
#                 : 950. 精度(テスト) = 0.9666666666666667
#                 : 1000. 誤差(テスト) = 0.12483396237756315
#                 : 1000. 精度(テスト) = 0.9666666666666667
# Loop7 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.07450197770829162
#                 : 50. 精度(テスト) = 0.9666666666666667
#                 : 100. 誤差(テスト) = 0.08709861003900056
#                 : 100. 精度(テスト) = 1.0
#                 : 150. 誤差(テスト) = 0.09006131135225987
#                 : 150. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.08409630033660166
#                 : 200. 精度(テスト) = 1.0
#                 : 250. 誤差(テスト) = 0.127232591380193
#                 : 250. 精度(テスト) = 0.9333333333333333
#                 : 300. 誤差(テスト) = 0.08735686308554531
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 350. 誤差(テスト) = 0.09344609216942577
#                 : 350. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.09103110493446019
#                 : 400. 精度(テスト) = 1.0
#                 : 450. 誤差(テスト) = 0.08763196608701958
#                 : 450. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.08081284180048362
#                 : 500. 精度(テスト) = 0.9666666666666667
#                 : 550. 誤差(テスト) = 0.08655794383599127
#                 : 550. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.08239178963537232
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 650. 誤差(テスト) = 0.0813751402990309
#                 : 650. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.08541947343125418
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 750. 誤差(テスト) = 0.08350998360559707
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.08540484071435527
#                 : 800. 精度(テスト) = 0.9666666666666667
#                 : 850. 誤差(テスト) = 0.09475745927800812
#                 : 850. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.08427215460592885
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 950. 誤差(テスト) = 0.12799344704608917
#                 : 950. 精度(テスト) = 0.9333333333333333
#                 : 1000. 誤差(テスト) = 0.10235768218184532
#                 : 1000. 精度(テスト) = 1.0
# Loop8 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.042452173537471334
#                 : 50. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.039505633123613416
#                 : 100. 精度(テスト) = 1.0
#                 : 150. 誤差(テスト) = 0.05032801397697981
#                 : 150. 精度(テスト) = 1.0
#                 : 200. 誤差(テスト) = 0.039541996032894704
#                 : 200. 精度(テスト) = 1.0
#                 : 250. 誤差(テスト) = 0.045720844224715444
#                 : 250. 精度(テスト) = 1.0
#                 : 300. 誤差(テスト) = 0.04645733296901997
#                 : 300. 精度(テスト) = 1.0
#                 : 350. 誤差(テスト) = 0.034653087488337515
#                 : 350. 精度(テスト) = 1.0
#                 : 400. 誤差(テスト) = 0.05427848741444338
#                 : 400. 精度(テスト) = 1.0
#                 : 450. 誤差(テスト) = 0.036822735473225024
#                 : 450. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.05983016554840992
#                 : 500. 精度(テスト) = 1.0
#                 : 550. 誤差(テスト) = 0.058730257027482025
#                 : 550. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.04124778834102751
#                 : 600. 精度(テスト) = 1.0
#                 : 650. 誤差(テスト) = 0.034928354783483634
#                 : 650. 精度(テスト) = 1.0
#                 : 700. 誤差(テスト) = 0.0413385336154117
#                 : 700. 精度(テスト) = 1.0
#                 : 750. 誤差(テスト) = 0.042257390919949935
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.04157462770027808
#                 : 800. 精度(テスト) = 1.0
#                 : 850. 誤差(テスト) = 0.03758806556573086
#                 : 850. 精度(テスト) = 1.0
#                 : 900. 誤差(テスト) = 0.03693968149501495
#                 : 900. 精度(テスト) = 1.0
#                 : 950. 誤差(テスト) = 0.05335143560063597
#                 : 950. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.05210324008671554
#                 : 1000. 精度(テスト) = 1.0
# Loop9 データ読み込み完了
#                 : 50. 誤差(テスト) = 0.06679703914687993
#                 : 50. 精度(テスト) = 1.0
#                 : 100. 誤差(テスト) = 0.08834287013190364
#                 : 100. 精度(テスト) = 0.9666666666666667
#                 : 150. 誤差(テスト) = 0.0675991404431692
#                 : 150. 精度(テスト) = 0.9666666666666667
#                 : 200. 誤差(テスト) = 0.06944205083820836
#                 : 200. 精度(テスト) = 1.0
#                 : 250. 誤差(テスト) = 0.060515334783076344
#                 : 250. 精度(テスト) = 0.9666666666666667
#                 : 300. 誤差(テスト) = 0.06432677366362717
#                 : 300. 精度(テスト) = 0.9666666666666667
#                 : 350. 誤差(テスト) = 0.07828043222249807
#                 : 350. 精度(テスト) = 0.9666666666666667
#                 : 400. 誤差(テスト) = 0.0665000223845915
#                 : 400. 精度(テスト) = 0.9666666666666667
#                 : 450. 誤差(テスト) = 0.060163579678264884
#                 : 450. 精度(テスト) = 1.0
#                 : 500. 誤差(テスト) = 0.07036856895208858
#                 : 500. 精度(テスト) = 1.0
#                 : 550. 誤差(テスト) = 0.06137241451511877
#                 : 550. 精度(テスト) = 1.0
#                 : 600. 誤差(テスト) = 0.07262826207799437
#                 : 600. 精度(テスト) = 0.9666666666666667
#                 : 650. 誤差(テスト) = 0.0833134013855966
#                 : 650. 精度(テスト) = 0.9666666666666667
#                 : 700. 誤差(テスト) = 0.08949209385706705
#                 : 700. 精度(テスト) = 0.9666666666666667
#                 : 750. 誤差(テスト) = 0.06643073339621271
#                 : 750. 精度(テスト) = 1.0
#                 : 800. 誤差(テスト) = 0.059244331462039
#                 : 800. 精度(テスト) = 1.0
#                 : 850. 誤差(テスト) = 0.06781001721990136
#                 : 850. 精度(テスト) = 0.9666666666666667
#                 : 900. 誤差(テスト) = 0.08381975053288589
#                 : 900. 精度(テスト) = 0.9666666666666667
#                 : 950. 誤差(テスト) = 0.064215847004246
#                 : 950. 精度(テスト) = 1.0
#                 : 1000. 誤差(テスト) = 0.06852716173337266
#                 : 1000. 精度(テスト) = 0.9666666666666667

# %%
# グラフの表示
plt.ylim(0, 1.02)
plt.axhline(y=1, linewidth=1, color='lightgray')
for i in range(tests_num+1):
    x = iters_num * i
    plt.axvline(x, linewidth=1, color='lightgray')

lists = range(0, iters_num*tests_num, plot_interval)
plt.plot(lists, losses, label="loss - training set")
plt.plot(lists, losses_test,  label="loss - test set")
plt.plot(lists, accuracies, label="acc - training set")
plt.plot(lists, accuracies_test, label="acc - test set")
plt.title("loss/accuracy")
plt.xlabel("iteration x data sets")
plt.ylabel("loss/accuracy")
plt.legend(loc='best',
           bbox_to_anchor=(1.01, 0.8, 0.4, .100), 
           borderaxespad=0.,)

plt.savefig("output.jpg", bbox_inches='tight')
plt.show()
